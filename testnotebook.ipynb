# %%
import xml.etree.ElementTree as ET
import os
import pandas as pd

# %%
df = pd.read_parquet('export/ReportsFinStatements_balance_sheet_annual.parquet')

# %%
df.head(3)
# Out:
#    ACSH       ACAE  ASTI       SCSI        AACR        ATRC        AITL  \
# 0  None  35.100000  None  35.100000  535.500000  537.600000  249.500000
# 0  None   5.376000  None   5.376000  161.632000  166.147000   73.942000
# 0  None   2.952000  None   2.952000   72.744000   73.624000   56.598000
#
#         APPY  SOCA        ATCA  ... FiscalPeriodYear symbol  \
# 0  43.200000  None  865.400000  ...             2022   ACDC
# 0   6.213000  None  251.678000  ...             2021   ACDC
# 0   6.516000  None  139.690000  ...             2020   ACDC
#
#              reportType  ACDB  SOEA  ANTL  SOAT  LDBT  SOBL  LSTB
# 0  ReportsFinStatements  None  None  None  None  None  None  None
# 0  ReportsFinStatements  None  None  None  None  None  None  None
# 0  ReportsFinStatements  None  None  None  None  None  None  None
#
# [3 rows x 69 columns]
